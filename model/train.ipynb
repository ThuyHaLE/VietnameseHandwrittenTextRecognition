# %%
# !pip -q install -U scikit-image
# !pip -q install einops
# !pip -q install lmdb
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.7/14.7 MB 75.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 1.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 299.2/299.2 kB 5.0 MB/s eta 0:00:00

# %%
#Load model and weights
# !gdown 1VU-qucVHcNbu2qnGkWWNwO0TRhY-7iH2
# !unzip -q vietocr.zip
#Import model
from vietocr import *
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1VU-qucVHcNbu2qnGkWWNwO0TRhY-7iH2
# To: /content/vietocr.zip
# 100% 142M/142M [00:03<00:00, 45.2MB/s]

# %%
#Load dataset
# !gdown 1t2esUsD8cPql51XnC_AQ667GoKyRr7of
# !unzip -q data.zip

# %%
#Load config
def load_config(yml_path):
  with open(yml_path, "r") as stream:
    try:
      config = yaml.safe_load(stream)
      return config
    except yaml.YAMLError as exc:
      print(exc)
config = load_config('/content/base.yml')

# %%
model = Trainer(config)
model.train()
